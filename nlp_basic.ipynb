# %%
text="""India, officially the Republic of India (Hindi: Bhārat Gaṇarājya), is a country in South Asia. It is the seventh-largest country by area, the second-most populous country, and the most populous democracy in the world. Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west; China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east. In the Indian Ocean, India is in the vicinity of Sri Lanka and the Maldives; its Andaman and Nicobar Islands share a maritime border with Thailand, Myanmar, and Indonesia. 
Modern humans arrived on the Indian subcontinent from Africa no later than 55,000 years ago. Their long occupation, initially in varying forms of isolation as hunter-gatherers, has made the region highly diverse, second only to Africa in human genetic diversity. Settled life emerged on the subcontinent in the western margins of the Indus river basin 9,000 years ago, evolving gradually into the Indus Valley Civilisation of the third millennium BCE. By 1200 BCE, an archaic form of Sanskrit, an Indo-European language, had diffused into India from the northwest. Its evidence today is found in the hymns of the Rigveda. Preserved by a resolutely vigilant oral tradition, the Rigveda records the dawning of Hinduism in India. The Dravidian languages of India were supplanted in the northern and western regions. By 400 BCE, stratification and exclusion by caste had emerged within Hinduism, and Buddhism and Jainism had arisen, proclaiming social orders unlinked to heredity. Early political consolidations gave rise to the loose-knit Maurya and Gupta Empires based in the Ganges Basin. Their collective era was suffused with wide-ranging creativity, but also marked by the declining status of women, and the incorporation of untouchability into an organised system of belief. In South India, the Middle kingdoms exported Dravidian-languages scripts and religious cultures to the kingdoms of Southeast Asia.
"""

# %%
#Q1: Apply word tokenization on the above text.
import spacy

nlp = spacy.load('en_core_web_sm')
doc= nlp(text)
tokens=[token.text for token in doc]
print(tokens)
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# ['India', ',', 'officially', 'the', 'Republic', 'of', 'India', '(', 'Hindi', ':', 'Bhārat', 'Gaṇarājya', ')', ',', 'is', 'a', 'country', 'in', 'South', 'Asia', '.', 'It', 'is', 'the', 'seventh', '-', 'largest', 'country', 'by', 'area', ',', 'the', 'second', '-', 'most', 'populous', 'country', ',', 'and', 'the', 'most', 'populous', 'democracy', 'in', 'the', 'world', '.', 'Bounded', 'by', 'the', 'Indian', 'Ocean', 'on', 'the', 'south', ',', 'the', 'Arabian', 'Sea', 'on', 'the', 'southwest', ',', 'and', 'the', 'Bay', 'of', 'Bengal', 'on', 'the', 'southeast', ',', 'it', 'shares', 'land', 'borders', 'with', 'Pakistan', 'to', 'the', 'west', ';', 'China', ',', 'Nepal', ',', 'and', 'Bhutan', 'to', 'the', 'north', ';', 'and', 'Bangladesh', 'and', 'Myanmar', 'to', 'the', 'east', '.', 'In', 'the', 'Indian', 'Ocean', ',', 'India', 'is', 'in', 'the', 'vicinity', 'of', 'Sri', 'Lanka', 'and', 'the', 'Maldives', ';', 'its', 'Andaman', 'and', 'Nicobar', 'Islands', 'share', 'a', 'maritime', 'border', 'with', 'Thailand', ',', 'Myanmar', ',', 'and', 'Indonesia', '.', '\n', 'Modern', 'humans', 'arrived', 'on', 'the', 'Indian', 'subcontinent', 'from', 'Africa', 'no', 'later', 'than', '55,000', 'years', 'ago', '.', 'Their', 'long', 'occupation', ',', 'initially', 'in', 'varying', 'forms', 'of', 'isolation', 'as', 'hunter', '-', 'gatherers', ',', 'has', 'made', 'the', 'region', 'highly', 'diverse', ',', 'second', 'only', 'to', 'Africa', 'in', 'human', 'genetic', 'diversity', '.', 'Settled', 'life', 'emerged', 'on', 'the', 'subcontinent', 'in', 'the', 'western', 'margins', 'of', 'the', 'Indus', 'river', 'basin', '9,000', 'years', 'ago', ',', 'evolving', 'gradually', 'into', 'the', 'Indus', 'Valley', 'Civilisation', 'of', 'the', 'third', 'millennium', 'BCE', '.', 'By', '1200', 'BCE', ',', 'an', 'archaic', 'form', 'of', 'Sanskrit', ',', 'an', 'Indo', '-', 'European', 'language', ',', 'had', 'diffused', 'into', 'India', 'from', 'the', 'northwest', '.', 'Its', 'evidence', 'today', 'is', 'found', 'in', 'the', 'hymns', 'of', 'the', 'Rigveda', '.', 'Preserved', 'by', 'a', 'resolutely', 'vigilant', 'oral', 'tradition', ',', 'the', 'Rigveda', 'records', 'the', 'dawning', 'of', 'Hinduism', 'in', 'India', '.', 'The', 'Dravidian', 'languages', 'of', 'India', 'were', 'supplanted', 'in', 'the', 'northern', 'and', 'western', 'regions', '.', 'By', '400', 'BCE', ',', 'stratification', 'and', 'exclusion', 'by', 'caste', 'had', 'emerged', 'within', 'Hinduism', ',', 'and', 'Buddhism', 'and', 'Jainism', 'had', 'arisen', ',', 'proclaiming', 'social', 'orders', 'unlinked', 'to', 'heredity', '.', 'Early', 'political', 'consolidations', 'gave', 'rise', 'to', 'the', 'loose', '-', 'knit', 'Maurya', 'and', 'Gupta', 'Empires', 'based', 'in', 'the', 'Ganges', 'Basin', '.', 'Their', 'collective', 'era', 'was', 'suffused', 'with', 'wide', '-', 'ranging', 'creativity', ',', 'but', 'also', 'marked', 'by', 'the', 'declining', 'status', 'of', 'women', ',', 'and', 'the', 'incorporation', 'of', 'untouchability', 'into', 'an', 'organised', 'system', 'of', 'belief', '.', 'In', 'South', 'India', ',', 'the', 'Middle', 'kingdoms', 'exported', 'Dravidian', '-', 'languages', 'scripts', 'and', 'religious', 'cultures', 'to', 'the', 'kingdoms', 'of', 'Southeast', 'Asia', '.', '\n']

# %%
###POS
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp(text)

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# India India PROPN NNP nsubj Xxxxx True False
# , , PUNCT , punct , False False
# officially officially ADV RB advmod xxxx True False
# the the DET DT det xxx True True
# Republic Republic PROPN NNP appos Xxxxx True False
# of of ADP IN prep xx True True
# India India PROPN NNP pobj Xxxxx True False
# ( ( PUNCT -LRB- punct ( False False
# Hindi Hindi PROPN NNP appos Xxxxx True False
# : : PUNCT : punct : False False
# Bhārat Bhārat PROPN NNP compound Xxxxx True False
# Gaṇarājya Gaṇarājya PROPN NNP appos Xxxxx True False
# ) ) PUNCT -RRB- punct ) False False
# , , PUNCT , punct , False False
# is be AUX VBZ ROOT xx True True
# a a DET DT det x True True
# country country NOUN NN attr xxxx True False
# in in ADP IN prep xx True True
# South South PROPN NNP compound Xxxxx True False
# Asia Asia PROPN NNP pobj Xxxx True False
# . . PUNCT . punct . False False
# It it PRON PRP nsubj Xx True True
# is be AUX VBZ ROOT xx True True
# the the DET DT det xxx True True
# seventh seventh ADV RB advmod xxxx True False
# - - PUNCT HYPH punct - False False
# largest large ADJ JJS amod xxxx True False
# country country NOUN NN attr xxxx True False
# by by ADP IN prep xx True True
# area area NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# the the DET DT det xxx True True
# second second ADV RB advmod xxxx True False
# - - PUNCT HYPH punct - False False
# most most ADV RBS advmod xxxx True True
# populous populous ADJ JJ amod xxxx True False
# country country NOUN NN appos xxxx True False
# , , PUNCT , punct , False False
# and and CCONJ CC cc xxx True True
# the the DET DT det xxx True True
# most most ADV RBS advmod xxxx True True
# populous populous ADJ JJ amod xxxx True False
# democracy democracy NOUN NN conj xxxx True False
# in in ADP IN prep xx True True
# the the DET DT det xxx True True
# world world NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# Bounded bound VERB VBN advcl Xxxxx True False
# by by ADP IN agent xx True True
# the the DET DT det xxx True True
# Indian Indian PROPN NNP compound Xxxxx True False
# Ocean Ocean PROPN NNP pobj Xxxxx True False
# on on ADP IN prep xx True True
# the the DET DT det xxx True True
# south south NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# the the DET DT det xxx True True
# Arabian Arabian PROPN NNP compound Xxxxx True False
# Sea Sea PROPN NNP nmod Xxx True False
# on on ADP IN prep xx True True
# the the DET DT det xxx True True
# southwest southwest NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# and and CCONJ CC cc xxx True True
# the the DET DT det xxx True True
# Bay Bay PROPN NNP conj Xxx True False
# of of ADP IN prep xx True True
# Bengal Bengal PROPN NNP pobj Xxxxx True False
# on on ADP IN prep xx True True
# the the DET DT det xxx True True
# southeast southeast NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# it it PRON PRP nsubj xx True True
# shares share VERB VBZ ROOT xxxx True False
# land land NOUN NN compound xxxx True False
# borders border NOUN NNS dobj xxxx True False
# with with ADP IN prep xxxx True True
# Pakistan Pakistan PROPN NNP pobj Xxxxx True False
# to to ADP IN prep xx True True
# the the DET DT det xxx True True
# west west NOUN NN pobj xxxx True False
# ; ; PUNCT : punct ; False False
# China China PROPN NNP npadvmod Xxxxx True False
# , , PUNCT , punct , False False
# Nepal Nepal PROPN NNP conj Xxxxx True False
# , , PUNCT , punct , False False
# and and CCONJ CC cc xxx True True
# Bhutan Bhutan PROPN NNP conj Xxxxx True False
# to to ADP IN prep xx True True
# the the DET DT det xxx True True
# north north NOUN NN pobj xxxx True False
# ; ; PUNCT : punct ; False False
# and and CCONJ CC cc xxx True True
# Bangladesh Bangladesh PROPN NNP conj Xxxxx True False
# and and CCONJ CC cc xxx True True
# Myanmar Myanmar PROPN NNP conj Xxxxx True False
# to to ADP IN prep xx True True
# the the DET DT det xxx True True
# east east NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# In in ADP IN prep Xx True True
# the the DET DT det xxx True True
# Indian Indian PROPN NNP compound Xxxxx True False
# Ocean Ocean PROPN NNP pobj Xxxxx True False
# , , PUNCT , punct , False False
# India India PROPN NNP nsubj Xxxxx True False
# is be AUX VBZ ccomp xx True True
# in in ADP IN prep xx True True
# the the DET DT det xxx True True
# vicinity vicinity NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# Sri Sri PROPN NNP compound Xxx True False
# Lanka Lanka PROPN NNP pobj Xxxxx True False
# and and CCONJ CC cc xxx True True
# the the DET DT det xxx True True
# Maldives Maldives PROPN NNPS conj Xxxxx True False
# ; ; PUNCT : punct ; False False
# its its PRON PRP$ poss xxx True True
# Andaman Andaman PROPN NNP nsubj Xxxxx True False
# and and CCONJ CC cc xxx True True
# Nicobar Nicobar PROPN NNP compound Xxxxx True False
# Islands Islands PROPN NNPS conj Xxxxx True False
# share share VERB VBP ROOT xxxx True False
# a a DET DT det x True True
# maritime maritime ADJ JJ amod xxxx True False
# border border NOUN NN dobj xxxx True False
# with with ADP IN prep xxxx True True
# Thailand Thailand PROPN NNP pobj Xxxxx True False
# , , PUNCT , punct , False False
# Myanmar Myanmar PROPN NNP appos Xxxxx True False
# , , PUNCT , punct , False False
# and and CCONJ CC cc xxx True True
# Indonesia Indonesia PROPN NNP conj Xxxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP dep
#  False False
# Modern modern ADJ JJ amod Xxxxx True False
# humans human NOUN NNS nsubj xxxx True False
# arrived arrive VERB VBD ROOT xxxx True False
# on on ADP IN prep xx True True
# the the DET DT det xxx True True
# Indian indian ADJ JJ amod Xxxxx True False
# subcontinent subcontinent NOUN NN pobj xxxx True False
# from from ADP IN prep xxxx True True
# Africa Africa PROPN NNP pobj Xxxxx True False
# no no ADV RB neg xx True True
# later later ADV RB advmod xxxx True False
# than than ADP IN quantmod xxxx True True
# 55,000 55,000 NUM CD nummod dd,ddd False False
# years year NOUN NNS npadvmod xxxx True False
# ago ago ADV RB advmod xxx True False
# . . PUNCT . punct . False False
# Their their PRON PRP$ poss Xxxxx True True
# long long ADJ JJ amod xxxx True False
# occupation occupation NOUN NN nsubj xxxx True False
# , , PUNCT , punct , False False
# initially initially ADV RB advmod xxxx True False
# in in ADP IN prep xx True True
# varying vary VERB VBG amod xxxx True False
# forms form NOUN NNS pobj xxxx True False
# of of ADP IN prep xx True True
# isolation isolation NOUN NN pobj xxxx True False
# as as ADP IN prep xx True True
# hunter hunter NOUN NN compound xxxx True False
# - - PUNCT HYPH punct - False False
# gatherers gatherer NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# has have AUX VBZ aux xxx True True
# made make VERB VBN ROOT xxxx True True
# the the DET DT det xxx True True
# region region NOUN NN nsubj xxxx True False
# highly highly ADV RB advmod xxxx True False
# diverse diverse ADJ JJ ccomp xxxx True False
# , , PUNCT , punct , False False
# second second ADJ JJ ccomp xxxx True False
# only only ADV RB advmod xxxx True True
# to to ADP IN prep xx True True
# Africa Africa PROPN NNP pobj Xxxxx True False
# in in ADP IN prep xx True True
# human human ADJ JJ amod xxxx True False
# genetic genetic ADJ JJ amod xxxx True False
# diversity diversity NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# Settled settled ADJ JJ amod Xxxxx True False
# life life NOUN NN nsubj xxxx True False
# emerged emerge VERB VBD ROOT xxxx True False
# on on ADP IN prep xx True True
# the the DET DT det xxx True True
# subcontinent subcontinent NOUN NN pobj xxxx True False
# in in ADP IN prep xx True True
# the the DET DT det xxx True True
# western western ADJ JJ amod xxxx True False
# margins margin NOUN NNS pobj xxxx True False
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# Indus Indus PROPN NNP compound Xxxxx True False
# river river PROPN NNP compound xxxx True False
# basin basin NOUN NN pobj xxxx True False
# 9,000 9,000 NUM CD nummod d,ddd False False
# years year NOUN NNS npadvmod xxxx True False
# ago ago ADV RB advmod xxx True False
# , , PUNCT , punct , False False
# evolving evolve VERB VBG advcl xxxx True False
# gradually gradually ADV RB advmod xxxx True False
# into into ADP IN prep xxxx True True
# the the DET DT det xxx True True
# Indus Indus PROPN NNP compound Xxxxx True False
# Valley Valley PROPN NNP compound Xxxxx True False
# Civilisation Civilisation PROPN NNP pobj Xxxxx True False
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# third third ADJ JJ amod xxxx True True
# millennium millennium NOUN NN pobj xxxx True False
# BCE BCE PROPN NNP pobj XXX True False
# . . PUNCT . punct . False False
# By by ADP IN prep Xx True True
# 1200 1200 NUM CD pobj dddd False False
# BCE BCE PROPN NNP nsubj XXX True False
# , , PUNCT , punct , False False
# an an DET DT det xx True True
# archaic archaic ADJ JJ amod xxxx True False
# form form NOUN NN appos xxxx True False
# of of ADP IN prep xx True True
# Sanskrit Sanskrit PROPN NNP pobj Xxxxx True False
# , , PUNCT , punct , False False
# an an DET DT det xx True True
# Indo indo ADJ JJ amod Xxxx True False
# - - PUNCT HYPH punct - False False
# European european ADJ JJ amod Xxxxx True False
# language language NOUN NN appos xxxx True False
# , , PUNCT , punct , False False
# had have AUX VBD aux xxx True True
# diffused diffuse VERB VBN ROOT xxxx True False
# into into ADP IN prep xxxx True True
# India India PROPN NNP pobj Xxxxx True False
# from from ADP IN prep xxxx True True
# the the DET DT det xxx True True
# northwest northwest NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# Its its PRON PRP$ poss Xxx True True
# evidence evidence NOUN NN nsubjpass xxxx True False
# today today NOUN NN npadvmod xxxx True False
# is be AUX VBZ auxpass xx True True
# found find VERB VBN ROOT xxxx True False
# in in ADP IN prep xx True True
# the the DET DT det xxx True True
# hymns hymn NOUN NNS pobj xxxx True False
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# Rigveda Rigveda PROPN NNP pobj Xxxxx True False
# . . PUNCT . punct . False False
# Preserved preserve VERB VBN advcl Xxxxx True False
# by by ADP IN agent xx True True
# a a DET DT det x True True
# resolutely resolutely ADV RB advmod xxxx True False
# vigilant vigilant ADJ JJ amod xxxx True False
# oral oral ADJ JJ amod xxxx True False
# tradition tradition NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# the the DET DT det xxx True True
# Rigveda Rigveda PROPN NNP nsubj Xxxxx True False
# records record VERB VBZ ROOT xxxx True False
# the the DET DT det xxx True True
# dawning dawning NOUN NN dobj xxxx True False
# of of ADP IN prep xx True True
# Hinduism Hinduism PROPN NNP pobj Xxxxx True False
# in in ADP IN prep xx True True
# India India PROPN NNP pobj Xxxxx True False
# . . PUNCT . punct . False False
# The the DET DT det Xxx True True
# Dravidian dravidian ADJ JJ amod Xxxxx True False
# languages language NOUN NNS nsubjpass xxxx True False
# of of ADP IN prep xx True True
# India India PROPN NNP pobj Xxxxx True False
# were be AUX VBD auxpass xxxx True True
# supplanted supplant VERB VBN ROOT xxxx True False
# in in ADP IN prep xx True True
# the the DET DT det xxx True True
# northern northern ADJ JJ amod xxxx True False
# and and CCONJ CC cc xxx True True
# western western ADJ JJ conj xxxx True False
# regions region NOUN NNS pobj xxxx True False
# . . PUNCT . punct . False False
# By by ADP IN prep Xx True True
# 400 400 NUM CD pobj ddd False False
# BCE BCE PROPN NNP nsubj XXX True False
# , , PUNCT , punct , False False
# stratification stratification NOUN NN conj xxxx True False
# and and CCONJ CC cc xxx True True
# exclusion exclusion NOUN NN conj xxxx True False
# by by ADP IN prep xx True True
# caste caste PROPN NNP pobj xxxx True False
# had have AUX VBD aux xxx True True
# emerged emerge VERB VBN ROOT xxxx True False
# within within ADP IN prep xxxx True True
# Hinduism Hinduism PROPN NNP pobj Xxxxx True False
# , , PUNCT , punct , False False
# and and CCONJ CC cc xxx True True
# Buddhism Buddhism PROPN NNP nsubj Xxxxx True False
# and and CCONJ CC cc xxx True True
# Jainism Jainism PROPN NNP conj Xxxxx True False
# had have AUX VBD aux xxx True True
# arisen arise VERB VBN conj xxxx True False
# , , PUNCT , punct , False False
# proclaiming proclaim VERB VBG advcl xxxx True False
# social social ADJ JJ amod xxxx True False
# orders order NOUN NNS dobj xxxx True False
# unlinked unlinked ADJ JJ acl xxxx True False
# to to PART TO prep xx True True
# heredity heredity NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# Early early ADJ JJ amod Xxxxx True False
# political political ADJ JJ amod xxxx True False
# consolidations consolidation NOUN NNS nsubj xxxx True False
# gave give VERB VBD ROOT xxxx True False
# rise rise NOUN NN dobj xxxx True False
# to to ADP IN prep xx True True
# the the DET DT det xxx True True
# loose loose ADV RB advmod xxxx True False
# - - PUNCT HYPH punct - False False
# knit knit VERB VBN amod xxxx True False
# Maurya Maurya PROPN NNPS pobj Xxxxx True False
# and and CCONJ CC cc xxx True True
# Gupta Gupta PROPN NNP compound Xxxxx True False
# Empires Empires PROPN NNPS conj Xxxxx True False
# based base VERB VBN prep xxxx True False
# in in ADP IN prep xx True True
# the the DET DT det xxx True True
# Ganges Ganges PROPN NNP compound Xxxxx True False
# Basin Basin PROPN NNP pobj Xxxxx True False
# . . PUNCT . punct . False False
# Their their PRON PRP$ poss Xxxxx True True
# collective collective ADJ JJ amod xxxx True False
# era era NOUN NN nsubjpass xxx True False
# was be AUX VBD auxpass xxx True True
# suffused suffuse VERB VBN ROOT xxxx True False
# with with ADP IN prep xxxx True True
# wide wide ADV RB advmod xxxx True False
# - - PUNCT HYPH punct - False False
# ranging range VERB VBG amod xxxx True False
# creativity creativity NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# but but CCONJ CC cc xxx True True
# also also ADV RB advmod xxxx True True
# marked mark VERB VBN conj xxxx True False
# by by ADP IN agent xx True True
# the the DET DT det xxx True True
# declining decline VERB VBG amod xxxx True False
# status status NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# women woman NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# and and CCONJ CC cc xxx True True
# the the DET DT det xxx True True
# incorporation incorporation NOUN NN conj xxxx True False
# of of ADP IN prep xx True True
# untouchability untouchability NOUN NN pobj xxxx True False
# into into ADP IN prep xxxx True True
# an an DET DT det xx True True
# organised organised ADJ JJ amod xxxx True False
# system system NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# belief belief NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# In in ADP IN prep Xx True True
# South South PROPN NNP compound Xxxxx True False
# India India PROPN NNP pobj Xxxxx True False
# , , PUNCT , punct , False False
# the the DET DT det xxx True True
# Middle Middle PROPN NNP amod Xxxxx True False
# kingdoms kingdom NOUN NNS nsubj xxxx True False
# exported export VERB VBD ROOT xxxx True False
# Dravidian dravidian ADJ JJ amod Xxxxx True False
# - - PUNCT HYPH punct - False False
# languages language NOUN NNS compound xxxx True False
# scripts script NOUN NNS dobj xxxx True False
# and and CCONJ CC cc xxx True True
# religious religious ADJ JJ amod xxxx True False
# cultures culture NOUN NNS conj xxxx True False
# to to ADP IN prep xx True True
# the the DET DT det xxx True True
# kingdoms kingdom NOUN NNS pobj xxxx True False
# of of ADP IN prep xx True True
# Southeast Southeast PROPN NNP compound Xxxxx True False
# Asia Asia PROPN NNP pobj Xxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP dep
#  False False

# %%
import spacy

# English pipelines include a rule-based lemmatizer
nlp = spacy.load("en_core_web_sm")
lemmatizer = nlp.get_pipe("lemmatizer")
print(lemmatizer.mode)  # 'rule'

doc = nlp(text)
print([token.lemma_ for token in doc])
# Out:
# rule
# ['India', ',', 'officially', 'the', 'Republic', 'of', 'India', '(', 'Hindi', ':', 'Bhārat', 'Gaṇarājya', ')', ',', 'be', 'a', 'country', 'in', 'South', 'Asia', '.', 'it', 'be', 'the', 'seventh', '-', 'large', 'country', 'by', 'area', ',', 'the', 'second', '-', 'most', 'populous', 'country', ',', 'and', 'the', 'most', 'populous', 'democracy', 'in', 'the', 'world', '.', 'bound', 'by', 'the', 'Indian', 'Ocean', 'on', 'the', 'south', ',', 'the', 'Arabian', 'Sea', 'on', 'the', 'southwest', ',', 'and', 'the', 'Bay', 'of', 'Bengal', 'on', 'the', 'southeast', ',', 'it', 'share', 'land', 'border', 'with', 'Pakistan', 'to', 'the', 'west', ';', 'China', ',', 'Nepal', ',', 'and', 'Bhutan', 'to', 'the', 'north', ';', 'and', 'Bangladesh', 'and', 'Myanmar', 'to', 'the', 'east', '.', 'in', 'the', 'Indian', 'Ocean', ',', 'India', 'be', 'in', 'the', 'vicinity', 'of', 'Sri', 'Lanka', 'and', 'the', 'Maldives', ';', 'its', 'Andaman', 'and', 'Nicobar', 'Islands', 'share', 'a', 'maritime', 'border', 'with', 'Thailand', ',', 'Myanmar', ',', 'and', 'Indonesia', '.', '\n', 'modern', 'human', 'arrive', 'on', 'the', 'indian', 'subcontinent', 'from', 'Africa', 'no', 'later', 'than', '55,000', 'year', 'ago', '.', 'their', 'long', 'occupation', ',', 'initially', 'in', 'vary', 'form', 'of', 'isolation', 'as', 'hunter', '-', 'gatherer', ',', 'have', 'make', 'the', 'region', 'highly', 'diverse', ',', 'second', 'only', 'to', 'Africa', 'in', 'human', 'genetic', 'diversity', '.', 'settled', 'life', 'emerge', 'on', 'the', 'subcontinent', 'in', 'the', 'western', 'margin', 'of', 'the', 'Indus', 'river', 'basin', '9,000', 'year', 'ago', ',', 'evolve', 'gradually', 'into', 'the', 'Indus', 'Valley', 'Civilisation', 'of', 'the', 'third', 'millennium', 'BCE', '.', 'by', '1200', 'BCE', ',', 'an', 'archaic', 'form', 'of', 'Sanskrit', ',', 'an', 'indo', '-', 'european', 'language', ',', 'have', 'diffuse', 'into', 'India', 'from', 'the', 'northwest', '.', 'its', 'evidence', 'today', 'be', 'find', 'in', 'the', 'hymn', 'of', 'the', 'Rigveda', '.', 'preserve', 'by', 'a', 'resolutely', 'vigilant', 'oral', 'tradition', ',', 'the', 'Rigveda', 'record', 'the', 'dawning', 'of', 'Hinduism', 'in', 'India', '.', 'the', 'dravidian', 'language', 'of', 'India', 'be', 'supplant', 'in', 'the', 'northern', 'and', 'western', 'region', '.', 'by', '400', 'BCE', ',', 'stratification', 'and', 'exclusion', 'by', 'caste', 'have', 'emerge', 'within', 'Hinduism', ',', 'and', 'Buddhism', 'and', 'Jainism', 'have', 'arise', ',', 'proclaim', 'social', 'order', 'unlinked', 'to', 'heredity', '.', 'early', 'political', 'consolidation', 'give', 'rise', 'to', 'the', 'loose', '-', 'knit', 'Maurya', 'and', 'Gupta', 'Empires', 'base', 'in', 'the', 'Ganges', 'Basin', '.', 'their', 'collective', 'era', 'be', 'suffuse', 'with', 'wide', '-', 'range', 'creativity', ',', 'but', 'also', 'mark', 'by', 'the', 'decline', 'status', 'of', 'woman', ',', 'and', 'the', 'incorporation', 'of', 'untouchability', 'into', 'an', 'organised', 'system', 'of', 'belief', '.', 'in', 'South', 'India', ',', 'the', 'Middle', 'kingdom', 'export', 'dravidian', '-', 'language', 'script', 'and', 'religious', 'culture', 'to', 'the', 'kingdom', 'of', 'Southeast', 'Asia', '.', '\n']

# %%
####porter stemmer

import nltk
nltk.download('porter_test')
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
stemmed_tokens = [stemmer.stem(token) for token in tokens]
print(stemmed_tokens)
# Out:
# ['india', ',', 'offici', 'the', 'republ', 'of', 'india', '(', 'hindi', ':', 'bhārat', 'gaṇarājya', ')', ',', 'is', 'a', 'countri', 'in', 'south', 'asia', '.', 'it', 'is', 'the', 'seventh', '-', 'largest', 'countri', 'by', 'area', ',', 'the', 'second', '-', 'most', 'popul', 'countri', ',', 'and', 'the', 'most', 'popul', 'democraci', 'in', 'the', 'world', '.', 'bound', 'by', 'the', 'indian', 'ocean', 'on', 'the', 'south', ',', 'the', 'arabian', 'sea', 'on', 'the', 'southwest', ',', 'and', 'the', 'bay', 'of', 'bengal', 'on', 'the', 'southeast', ',', 'it', 'share', 'land', 'border', 'with', 'pakistan', 'to', 'the', 'west', ';', 'china', ',', 'nepal', ',', 'and', 'bhutan', 'to', 'the', 'north', ';', 'and', 'bangladesh', 'and', 'myanmar', 'to', 'the', 'east', '.', 'in', 'the', 'indian', 'ocean', ',', 'india', 'is', 'in', 'the', 'vicin', 'of', 'sri', 'lanka', 'and', 'the', 'maldiv', ';', 'it', 'andaman', 'and', 'nicobar', 'island', 'share', 'a', 'maritim', 'border', 'with', 'thailand', ',', 'myanmar', ',', 'and', 'indonesia', '.', '\n', 'modern', 'human', 'arriv', 'on', 'the', 'indian', 'subcontin', 'from', 'africa', 'no', 'later', 'than', '55,000', 'year', 'ago', '.', 'their', 'long', 'occup', ',', 'initi', 'in', 'vari', 'form', 'of', 'isol', 'as', 'hunter', '-', 'gather', ',', 'ha', 'made', 'the', 'region', 'highli', 'divers', ',', 'second', 'onli', 'to', 'africa', 'in', 'human', 'genet', 'divers', '.', 'settl', 'life', 'emerg', 'on', 'the', 'subcontin', 'in', 'the', 'western', 'margin', 'of', 'the', 'indu', 'river', 'basin', '9,000', 'year', 'ago', ',', 'evolv', 'gradual', 'into', 'the', 'indu', 'valley', 'civilis', 'of', 'the', 'third', 'millennium', 'bce', '.', 'by', '1200', 'bce', ',', 'an', 'archaic', 'form', 'of', 'sanskrit', ',', 'an', 'indo', '-', 'european', 'languag', ',', 'had', 'diffus', 'into', 'india', 'from', 'the', 'northwest', '.', 'it', 'evid', 'today', 'is', 'found', 'in', 'the', 'hymn', 'of', 'the', 'rigveda', '.', 'preserv', 'by', 'a', 'resolut', 'vigil', 'oral', 'tradit', ',', 'the', 'rigveda', 'record', 'the', 'dawn', 'of', 'hinduism', 'in', 'india', '.', 'the', 'dravidian', 'languag', 'of', 'india', 'were', 'supplant', 'in', 'the', 'northern', 'and', 'western', 'region', '.', 'by', '400', 'bce', ',', 'stratif', 'and', 'exclus', 'by', 'cast', 'had', 'emerg', 'within', 'hinduism', ',', 'and', 'buddhism', 'and', 'jainism', 'had', 'arisen', ',', 'proclaim', 'social', 'order', 'unlink', 'to', 'hered', '.', 'earli', 'polit', 'consolid', 'gave', 'rise', 'to', 'the', 'loos', '-', 'knit', 'maurya', 'and', 'gupta', 'empir', 'base', 'in', 'the', 'gang', 'basin', '.', 'their', 'collect', 'era', 'wa', 'suffus', 'with', 'wide', '-', 'rang', 'creativ', ',', 'but', 'also', 'mark', 'by', 'the', 'declin', 'statu', 'of', 'women', ',', 'and', 'the', 'incorpor', 'of', 'untouch', 'into', 'an', 'organis', 'system', 'of', 'belief', '.', 'in', 'south', 'india', ',', 'the', 'middl', 'kingdom', 'export', 'dravidian', '-', 'languag', 'script', 'and', 'religi', 'cultur', 'to', 'the', 'kingdom', 'of', 'southeast', 'asia', '.', '\n']
# [nltk_data] Downloading package porter_test to /root/nltk_data...
# [nltk_data]   Unzipping stemmers/porter_test.zip.

# %%
######NER
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp(text)

for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# India 0 5 GPE
# the Republic of India 18 39 GPE
# South Asia 83 93 LOC
# seventh 105 112 ORDINAL
# second 142 148 ORDINAL
# the Indian Ocean 229 245 LOC
# the Arabian Sea 260 275 LOC
# the Bay of Bengal 298 315 FAC
# Pakistan 362 370 GPE
# China 384 389 GPE
# Nepal 391 396 GPE
# Bhutan 402 408 GPE
# Bangladesh 427 437 GPE
# Myanmar 442 449 GPE
# the Indian Ocean 466 482 LOC
# India 484 489 GPE
# Sri Lanka 512 521 GPE
# Maldives 530 538 ORG
# Andaman 544 551 FAC
# Nicobar Islands 556 571 GPE
# Thailand 601 609 GPE
# Myanmar 611 618 GPE
# Indonesia 624 633 GPE
# Modern 636 642 ORG
# Indian 665 671 NORP
# Africa 690 696 LOC
# second 849 855 ORDINAL
# Africa 864 870 LOC
# 9,000 years ago 988 1003 DATE
# the Indus Valley Civilisation 1029 1058 ORG
# third 1066 1071 ORDINAL
# BCE 1083 1086 ORG
# 1200 1091 1095 CARDINAL
# BCE 1096 1099 ORG
# Sanskrit 1120 1128 GPE
# India 1175 1180 GPE
# today 1214 1219 DATE
# Rigveda 1249 1256 ORG
# Rigveda 1313 1320 ORG
# Hinduism 1344 1352 NORP
# India 1356 1361 GPE
# Dravidian 1367 1376 NORP
# India 1390 1395 GPE
# 400 1452 1455 CARDINAL
# BCE 1456 1459 ORG
# Maurya 1672 1678 PERSON
# Gupta Empires 1683 1696 PERSON
# the Ganges Basin 1706 1722 LOC
# South India 1917 1928 GPE
# Dravidian 1959 1968 NORP
# Southeast Asia 2029 2043 LOC
